# %% [markdown]
# <a href="https://colab.research.google.com/github/xzy1426/ytp/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新增區段

# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount("/content/drive")


path = "/ytp/S__17506309.jpg"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image = cv2.imread(path)
print(type(image))
print(image.shape) # h, w, c
print(image)
# Out:
# <class 'numpy.ndarray'>
# (1494, 1096, 3)
# [[[ 36  37  35]
#   [ 36  37  35]
#   [ 36  37  35]
#   ...
#   [122 132 139]
#   [107 116 120]
#   [105 114 118]]
#
#  [[ 37  38  36]
#   [ 37  38  36]
#   [ 37  38  36]
#   ...
#   [120 130 137]
#   [105 114 118]
#   [105 114 118]]
#
#  [[ 36  37  35]
#   [ 36  37  35]
#   [ 36  37  35]
#   ...
#   [115 127 131]
#   [101 112 116]
#   [102 113 117]]
#
#  ...
#
#  [[114 119 117]
#   [115 120 118]
#   [115 120 118]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[113 118 116]
#   [115 120 118]
#   [116 121 119]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]
#
#  [[110 115 113]
#   [113 118 116]
#   [115 120 118]
#   ...
#   [  0   0   0]
#   [  0   0   0]
#   [  0   0   0]]]

# %%
plt.imshow(image) # cv2 (B, G, R)
plt.show()

# %%
new_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(new_image)
plt.show()
